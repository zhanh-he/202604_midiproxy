# %%
import os
os.environ["PROJECT_ROOT"] = "/media/mengh/SharedData/zhanh/synth-proxy_v1"

# !cd /media/mengh/SharedData/zhanh/synth-proxy_v1 && \
PROJECT_ROOT=/media/mengh/SharedData/zhanh/synth-proxy_v1 \
python src/sfproxy/export_dataset_pkl.py \
  --config-name export_salamander_piano \
  dataset_size=20000 \
  start_index=0 end_index=20000 \
  batch_size=8 num_workers=8
# Out:
# [2026-03-23 16:42:20,472][__main__][INFO] - Export configs
# [2026-03-23 16:42:20,472][__main__][INFO] - instrument: salamander_piano
# [2026-03-23 16:42:20,472][__main__][INFO] - instrument_type: sf2
# [2026-03-23 16:42:20,472][__main__][INFO] - sf2_path: /media/mengh/SharedData/zhanh/202601_midisemi_data/soundfront/SalamanderGrandPiano-SF2-V3+20200602/SalamanderGrandPiano-V3+20200602.sf2
# [2026-03-23 16:42:20,472][__main__][INFO] - bank: 0
# [2026-03-23 16:42:20,472][__main__][INFO] - program: 0
# [2026-03-23 16:42:20,472][__main__][INFO] - polyphony: 64
# [2026-03-23 16:42:20,472][__main__][INFO] - gain_db: -6.0
# [2026-03-23 16:42:20,472][__main__][INFO] - dataset_size: 20000
# [2026-03-23 16:42:20,472][__main__][INFO] - virtual_dataset_size: 20000
# [2026-03-23 16:42:20,472][__main__][INFO] - start_index: 0
# [2026-03-23 16:42:20,472][__main__][INFO] - end_index: 20000
# [2026-03-23 16:42:20,472][__main__][INFO] - seed_offset: 0
# ...

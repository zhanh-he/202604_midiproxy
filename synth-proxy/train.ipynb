# %% [markdown]
# # SFProxy Train
#
# Notebook 里直接跑训练。为了避免 Lightning 的 TQDM 在 notebook 输出里把 `Validation` 进度条刷得很乱，这里把 progress bar 关掉了。

# %%
# !python src/train.py \
  dataset.train.path=/media/mengh/SharedData/zhanh/202601_midisemi_data/synth-proxy_v0/data/salamander_piano/mixed_v2_2s_default/train \
  dataset.val.path=/media/mengh/SharedData/zhanh/202601_midisemi_data/synth-proxy_v0/data/salamander_piano/mixed_v2_2s_default/val \
  dataset.train.instrument_name=salamander_piano \
  dataset.val.instrument_name=salamander_piano

# %% [markdown]
# # Evaluation from SoundFont
#
# CC. [Piano Home](https://freepats.zenvoid.org/Piano/acoustic-grand-piano.html) OR in details.
# 1. [Salamander Grand Piano](https://sfzinstruments.github.io/pianos/salamander/)
#
#
# 1. Download Sfz Render in Linux
#
# ```bash
# # 1. Download Sfz Render in Linux
# sudo apt update
# sudo apt install -y git cmake ninja-build build-essential pkg-config libsndfile1-dev libjack-dev
# git clone https://github.com/sfztools/sfizz.git
# cd sfizz
# cmake -S . -B build -DCMAKE_BUILD_TYPE=Release -DSFIZZ_RENDER=ON -GNinja
# cmake --build build
# find build -maxdepth 4 -type f -perm -111 -iname "sfizz*render*"
# # If return build/clients/CMakeFiles/sfizz_render.dir/sfizz_render.cpp.o
# #           build/clients/sfizz_render.man
# #           build/library/bin/sfizz_render
# # Means the installation has been successed.
#
# # 2. Add to global path - use my case as example.
# # Replace "/media/mengh/SharedData/zhanh/202601_midisemi/sfizz" to your sfizz git-repo path.
# # echo 'export PATH="/media/datadisk/home/22828187/zhanh/sfizz/build/library/bin:$PATH"' >> ~/.bashrc
# echo 'export PATH="/media/mengh/SharedData/zhanh/202601_midisemi/sfizz/build/library/bin:$PATH"' >> ~/.bashrc
# source ~/.bashrc
# which sfizz_render # should return .../sfizz/build/library/bin/sfizz_render
#
# # 3. SF2 required fluidsynth
# sudo apt-get update
# sudo apt-get install -y fluidsynth libfluidsynth-dev
# pip install pyfluidsynth
# conda install -n dynest -c conda-forge fluidsynth
# ```

# %%
# Check fluidsynth installation
# !python -c "import sys; print(sys.executable)"
# !python -c "import fluidsynth; print('ok', fluidsynth.__file__)"
# Out:
# /home/mengh/miniconda3/envs/dynest/bin/python
# ok /home/mengh/miniconda3/envs/dynest/lib/python3.11/site-packages/fluidsynth.py

# %%
# %cd /media/mengh/SharedData/zhanh/202604_midiproxy/data_analysis
# !PATH=/media/mengh/SharedData/zhanh/202601_midisemi/sfizz/build/library/bin:$PATH \
PYTHONPATH=src python -m data_analysis.rendering.render_pair "/media/mengh/SharedData/zhanh/Dataset/FrancoisLeducGuitarDataset/midi/9wp4c.mid" \
  --instrument "/media/mengh/SharedData/zhanh/202601_midisemi_data/soundfont/SpanishClassicalGuitar-SFZ/SpanishClassicalGuitar-20190618.sfz" \
  --out_dir "/media/mengh/SharedData/zhanh/202601_midisemi_data/renders_guitar" \
  --sr 44100 \
  --flat_velocity 64

# %%
# %cd /media/mengh/SharedData/zhanh/202604_midiproxy/data_analysis
# %env PYTHONPATH=/media/mengh/SharedData/zhanh/202604_midiproxy/data_analysis/src

# %%
# Guitar SF2 vs FrancoisLeduc real audio
# !PYTHONPATH=src python -m data_analysis.cli.adv_render_and_eval_dataset \
  --dataset_type francoisleduc \
  --dataset_dir /media/mengh/SharedData/zhanh/Dataset/FrancoisLeducGuitarDataset \
  --split test \
  --instrument "/media/mengh/SharedData/zhanh/202601_midisemi_data/soundfont/SpanishClassicalGuitar/SpanishClassicalGuitar-20190618.sf2" \
  --out_dir "/media/mengh/SharedData/zhanh/202601_midisemi_data/adv_renders/francoisleduc_guitar_sf2" \
  --render_sr 44100 \
  --eval_sr 22050 \
  --flat_velocity 64 \
  --ntot_plot \
  --skip_existing # \ --skip_note_dynamics \ --pearson_only
# Out:
# FRANCOISLEDUC: 100%|█████| 9/9 [00:54<00:00,  6.00s/track, fail=0, ok=9, skip=0]
# Summary
#   dataset: francoisleduc
#   scanned/ok/fail/skip_render: 9/9/0/0
#   dataset_dir: /media/mengh/SharedData/zhanh/Dataset/FrancoisLeducGuitarDataset
#   instrument: /media/mengh/SharedData/zhanh/202601_midisemi_data/soundfont/SpanishClassicalGuitar/SpanishClassicalGuitar-20190618.sf2
#   split: test
#
# real_vs_gt
#            BSSL                  NTOT                  Note Harmonic Energy  Note Onset Flux
#   pearson: 0.745167              0.660283              0.463112              0.386227
#   cosine : 0.873914              0.660283              0.973640              0.864343
#   mae    : 0.574199              2.598704              0.755179              0.022220
#
# real_vs_pred
#            BSSL                  NTOT                  Note Harmonic Energy  Note Onset Flux
#   pearson: 0.735249              0.615090              0.156735              0.426006
# ...

# %%
# Guitar SFZ vs FrancoisLeduc real audio
# !PYTHONPATH=src python -m data_analysis.cli.adv_render_and_eval_dataset \
  --dataset_type francoisleduc \
  --dataset_dir /media/mengh/SharedData/zhanh/Dataset/FrancoisLeducGuitarDataset \
  --split test \
  --instrument "/media/mengh/SharedData/zhanh/202601_midisemi_data/soundfont/SpanishClassicalGuitar/SpanishClassicalGuitar-20190618.sfz" \
  --out_dir "/media/mengh/SharedData/zhanh/202601_midisemi_data/adv_renders/francoisleduc_guitar_sfz" \
  --render_sr 44100 \
  --eval_sr 22050 \
  --flat_velocity 64 \
  --ntot_plot \
  --skip_existing # \ --skip_note_dynamics \ --pearson_only
# Out:
# FRANCOISLEDUC: 100%|█████| 9/9 [01:01<00:00,  6.87s/track, fail=0, ok=9, skip=0]
# Summary
#   dataset: francoisleduc
#   scanned/ok/fail/skip_render: 9/9/0/0
#   dataset_dir: /media/mengh/SharedData/zhanh/Dataset/FrancoisLeducGuitarDataset
#   instrument: /media/mengh/SharedData/zhanh/202601_midisemi_data/soundfont/SpanishClassicalGuitar/SpanishClassicalGuitar-20190618.sfz
#   split: test
#
# real_vs_gt
#            BSSL                  NTOT                  Note Harmonic Energy  Note Onset Flux
#   pearson: 0.744810              0.651106              0.461000              0.388381
#   cosine : 0.874553              0.651106              0.973566              0.865362
#   mae    : 0.577232              2.617291              0.760235              0.022295
#
# real_vs_pred
#            BSSL                  NTOT                  Note Harmonic Energy  Note Onset Flux
#   pearson: 0.734308              0.599678              0.152904              0.428595
# ...

# %%
# Guitar SF2 vs GAPS real audio
# !PYTHONPATH=src python -m data_analysis.cli.adv_render_and_eval_dataset \
  --dataset_type gaps \
  --dataset_dir /media/mengh/SharedData/zhanh/Dataset/GAPS \
  --split test \
  --instrument "/media/mengh/SharedData/zhanh/202601_midisemi_data/soundfont/SpanishClassicalGuitar/SpanishClassicalGuitar-20190618.sf2" \
  --out_dir "/media/mengh/SharedData/zhanh/202601_midisemi_data/adv_renders/gaps_guitar_sf2" \
  --render_sr 44100 \
  --eval_sr 22050 \
  --flat_velocity 64 \
  --ntot_plot \
  --skip_existing
# Out:
# GAPS: 100%|███████████| 30/30 [02:53<00:00,  5.77s/track, fail=0, ok=30, skip=0]
# Summary
#   dataset: gaps
#   scanned/ok/fail/skip_render: 30/30/0/0
#   dataset_dir: /media/mengh/SharedData/zhanh/Dataset/GAPS
#   instrument: /media/mengh/SharedData/zhanh/202601_midisemi_data/soundfont/SpanishClassicalGuitar/SpanishClassicalGuitar-20190618.sf2
#   split: test
#
# real_vs_gt
#            BSSL                  NTOT                  Note Harmonic Energy  Note Onset Flux
#   pearson: 0.734497              0.700203              0.176572              0.419751
#   cosine : 0.870808              0.700203              0.983212              0.890466
#   mae    : 0.654805              2.613593              0.631160              0.033067
#
# real_vs_pred
#            BSSL                  NTOT                  Note Harmonic Energy  Note Onset Flux
#   pearson: 0.733718              0.699174              0.176980              0.419751
# ...

# %%
# Guitar SF2 vs GAPS real audio
# !PYTHONPATH=src python -m data_analysis.cli.adv_render_and_eval_dataset \
  --dataset_type gaps \
  --dataset_dir /media/mengh/SharedData/zhanh/Dataset/GAPS \
  --split test \
  --instrument "/media/mengh/SharedData/zhanh/202601_midisemi_data/soundfont/SpanishClassicalGuitar/SpanishClassicalGuitar-20190618.sfz" \
  --out_dir "/media/mengh/SharedData/zhanh/202601_midisemi_data/adv_renders/gaps_guitar_sfz" \
  --render_sr 44100 \
  --eval_sr 22050 \
  --flat_velocity 64 \
  --ntot_plot \
  --skip_existing
# Out:
# GAPS: 100%|███████████| 30/30 [12:51<00:00, 25.72s/track, fail=0, ok=30, skip=0]
# Summary
#   dataset: gaps
#   scanned/ok/fail/skip_render: 30/30/0/0
#   dataset_dir: /media/mengh/SharedData/zhanh/Dataset/GAPS
#   instrument: /media/mengh/SharedData/zhanh/202601_midisemi_data/soundfont/SpanishClassicalGuitar/SpanishClassicalGuitar-20190618.sfz
#   split: test
#
# real_vs_gt
#            BSSL                  NTOT                  Note Harmonic Energy  Note Onset Flux
#   pearson: 0.735230              0.698395              0.178840              0.422402
#   cosine : 0.871793              0.698395              0.983213              0.891124
#   mae    : 0.654001              2.614157              0.634636              0.032756
#
# real_vs_pred
#            BSSL                  NTOT                  Note Harmonic Energy  Note Onset Flux
#   pearson: 0.734485              0.697036              0.179255              0.422401
# ...

# %%
# !PYTHONPATH=src python -m data_analysis.cli.adv_render_and_eval_dataset \
  --dataset_type maestro \
  --dataset_dir /media/mengh/SharedData/zhanh/Dataset/maestro-v3.0.0 \
  --split test \
  --instrument "/media/mengh/SharedData/zhanh/202601_midisemi_data/soundfont/SalamanderGrandPiano/SalamanderGrandPiano-V3+20200602.sf2" \
  --out_dir "/media/mengh/SharedData/zhanh/202601_midisemi_data/adv_renders/maestro_salamanderpiano_sf2" \
  --render_sr 44100 \
  --eval_sr 22050 \
  --flat_velocity 64 \
  --ntot_plot \
  --skip_existing
# Out:
# MAESTRO: 100%|███| 177/177 [1:15:25<00:00, 25.57s/track, fail=0, ok=177, skip=0]
# Summary
#   dataset: maestro
#   scanned/ok/fail/skip_render: 177/177/0/0
#   dataset_dir: /media/mengh/SharedData/zhanh/Dataset/maestro-v3.0.0
#   instrument: /media/mengh/SharedData/zhanh/202601_midisemi_data/soundfont/SalamanderGrandPiano/SalamanderGrandPiano-V3+20200602.sf2
#   split: test
#
# real_vs_gt
#            BSSL                  NTOT                  Note Harmonic Energy  Note Onset Flux
#   pearson: 0.870991              0.904777              0.805683              0.913550
#   cosine : 0.932946              0.904777              0.978494              0.968200
#   mae    : 0.774768              4.118050              1.104455              0.032554
#
# real_vs_pred
#            BSSL                  NTOT                  Note Harmonic Energy  Note Onset Flux
#   pearson: 0.748756              0.603328              0.416538              0.498587
# ...

# %% [markdown]
# # Set to 64 - Piano Comparison

# %%
# !PYTHONPATH=src python -m data_analysis.cli.adv_render_and_eval_dataset \
  --dataset_type maestro \
  --dataset_dir /media/mengh/SharedData/zhanh/Dataset/maestro-v3.0.0 \
  --split test \
  --instrument "/media/mengh/SharedData/zhanh/202601_midisemi_data/soundfont/SalamanderGrandPiano/SalamanderGrandPianoV3.sfz" \
  --out_dir "/media/mengh/SharedData/zhanh/202601_midisemi_data/adv_renders/maestro_salamanderpiano_sfz" \
  --render_sr 44100 \
  --eval_sr 22050 \
  --flat_velocity 64 \
  --ntot_plot \
  --skip_existing
# Out:
# MAESTRO: 100%|███| 177/177 [49:04<00:00, 16.64s/track, fail=4, ok=173, skip=176]
# Summary
#   dataset: maestro
#   scanned/ok/fail/skip_render: 177/173/4/176
#   dataset_dir: /media/mengh/SharedData/zhanh/Dataset/maestro-v3.0.0
#   instrument: /media/mengh/SharedData/zhanh/202601_midisemi_data/soundfont/SalamanderGrandPiano/SalamanderGrandPianoV3.sfz
#   split: test
#
# real_vs_gt
#            BSSL                  NTOT                  Note Harmonic Energy  Note Onset Flux
#   pearson: 0.869984              0.882887              0.774340              0.902894
#   cosine : 0.938772              0.974832              0.986689              0.972374
#   mae    : 0.702418              3.705788              0.929304              0.030924
#
# real_vs_pred
#            BSSL                  NTOT                  Note Harmonic Energy  Note Onset Flux
#   pearson: 0.751872              0.619873              0.411373              0.515184
# ...

# %%
# !PYTHONPATH=src python -m data_analysis.cli.adv_render_and_eval_dataset \
  --dataset_type maestro \
  --dataset_dir /media/mengh/SharedData/zhanh/Dataset/maestro-v3.0.0 \
  --split test \
  --instrument "/media/mengh/SharedData/zhanh/202601_midisemi_data/soundfont/YDP-GrandPiano/YDP-GrandPiano-20160804.sf2" \
  --out_dir "/media/mengh/SharedData/zhanh/202601_midisemi_data/adv_renders/maestro_ydp_piano_sf2" \
  --render_sr 44100 \
  --eval_sr 22050 \
  --flat_velocity 64 \
  --ntot_plot \
  --skip_existing
# Out:
# MAESTRO: 100%|███| 177/177 [41:06<00:00, 13.93s/track, fail=0, ok=177, skip=177]
# Summary
#   dataset: maestro
#   scanned/ok/fail/skip_render: 177/177/0/177
#   dataset_dir: /media/mengh/SharedData/zhanh/Dataset/maestro-v3.0.0
#   instrument: /media/mengh/SharedData/zhanh/202601_midisemi_data/soundfont/YDP-GrandPiano/YDP-GrandPiano-20160804.sf2
#   split: test
#
# real_vs_gt
#            BSSL                  NTOT                  Note Harmonic Energy  Note Onset Flux
#   pearson: 0.836266              0.872366              0.820050              0.885712
#   cosine : 0.925510              0.973037              0.990805              0.966159
#   mae    : 0.509887              1.982864              0.445767              0.016597
#
# real_vs_pred
#            BSSL                  NTOT                  Note Harmonic Energy  Note Onset Flux
#   pearson: 0.732865              0.616845              0.425033              0.496403
# ...

# %% [markdown]
# # Set velocity to 80

# %%
# !PYTHONPATH=src python -m data_analysis.cli.adv_render_and_eval_dataset \
  --dataset_type maestro \
  --dataset_dir /media/mengh/SharedData/zhanh/Dataset/maestro-v3.0.0 \
  --split test \
  --instrument "/media/mengh/SharedData/zhanh/202601_midisemi_data/soundfont/SalamanderGrandPiano/SalamanderGrandPianoV3.sfz" \
  --out_dir "/media/mengh/SharedData/zhanh/202601_midisemi_data/adv_renders/maestro_salamanderpiano_sfz" \
  --render_sr 44100 \
  --eval_sr 22050 \
  --flat_velocity 80 \
  --ntot_plot \
  --skip_existing
# Out:
# MAESTRO: 100%|███| 177/177 [38:18<00:00, 12.99s/track, fail=1, ok=176, skip=176]
# Summary
#   dataset: maestro
#   scanned/ok/fail/skip_render: 177/176/1/176
#   dataset_dir: /media/mengh/SharedData/zhanh/Dataset/maestro-v3.0.0
#   instrument: /media/mengh/SharedData/zhanh/202601_midisemi_data/soundfont/SalamanderGrandPiano/SalamanderGrandPianoV3.sfz
#   split: test
#
# real_vs_gt
#            BSSL                  NTOT                  Note Harmonic Energy  Note Onset Flux
#   pearson: 0.870248              0.883239              0.776083              0.903497
#   cosine : 0.938782              0.974824              0.986634              0.972370
#   mae    : 0.696194              3.669527              0.921884              0.030556
#
# real_vs_pred
#            BSSL                  NTOT                  Note Harmonic Energy  Note Onset Flux
#   pearson: 0.746712              0.616292              0.411412              0.517195
# ...

# %%
# !PYTHONPATH=src python -m data_analysis.cli.adv_render_and_eval_dataset \
  --dataset_type maestro \
  --dataset_dir /media/mengh/SharedData/zhanh/Dataset/maestro-v3.0.0 \
  --split test \
  --instrument "/media/mengh/SharedData/zhanh/202601_midisemi_data/soundfont/YDP-GrandPiano/YDP-GrandPiano-20160804.sf2" \
  --out_dir "/media/mengh/SharedData/zhanh/202601_midisemi_data/adv_renders/maestro_ydp_piano_sf2" \
  --render_sr 44100 \
  --eval_sr 22050 \
  --flat_velocity 80 \
  --ntot_plot \
  --skip_existing
# Out:
# MAESTRO: 100%|███| 177/177 [43:32<00:00, 14.76s/track, fail=0, ok=177, skip=177]
# Summary
#   dataset: maestro
#   scanned/ok/fail/skip_render: 177/177/0/177
#   dataset_dir: /media/mengh/SharedData/zhanh/Dataset/maestro-v3.0.0
#   instrument: /media/mengh/SharedData/zhanh/202601_midisemi_data/soundfont/YDP-GrandPiano/YDP-GrandPiano-20160804.sf2
#   split: test
#
# real_vs_gt
#            BSSL                  NTOT                  Note Harmonic Energy  Note Onset Flux
#   pearson: 0.836266              0.872366              0.820050              0.885712
#   cosine : 0.925510              0.973037              0.990805              0.966159
#   mae    : 0.509887              1.982864              0.445767              0.016597
#
# real_vs_pred
#            BSSL                  NTOT                  Note Harmonic Energy  Note Onset Flux
#   pearson: 0.720493              0.619560              0.421205              0.497621
# ...

# %% [markdown]
# # Highlighting Results

# %%
from src.data_analysis.analysis import plot_velocity_metrics as pvm

pvm.SAVE_PNG = False   # 只在 notebook 里显示
# pvm.SAVE_PNG = True
# pvm.SAVE_DIR = "/media/mengh/SharedData/zhanh/202604_midiproxy/data_analysis/figures"

pvm.FIGSIZE = (5, 3)   # 原来是 (8.5, 4.8)
pvm.DPI = 300              # 存 paper 图建议高一点
pvm.SAVE_PNG = False       # 只在 notebook 里看就关掉

pvm.plot_fig1()
pvm.plot_fig2()
pvm.plot_fig3()
pvm.plot_fig4()

# %% [markdown]
# # Audio BSSL Loudness Statistics
#
# 统计不同数据集（MAESTRO / GOAT / GuitarSet）的 BSSL (Ntot) 分布，可单独或批量运行；在列表中注释/启用即可。

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd() / "src"))

# %run -m data_analysis.analysis.dataset_bssl_stats \
  --dataset "MAESTRO v3" \
  --root "/media/mengh/SharedData/zhanh/Dataset/maestro-v3.0.0" \
  --x-max 40

# %run -m data_analysis.analysis.dataset_bssl_stats \
  --dataset "SMD" \
  --root "/media/mengh/SharedData/zhanh/Dataset/SMD" \
  --x-max 40
#   --patterns "**/*.wav"

# %run -m data_analysis.analysis.dataset_bssl_stats \
  --dataset "MAPS" \
  --root "/media/mengh/SharedData/zhanh/Dataset/MAPS" \
  --patterns "ENSTDkCl/**/*.wav" "ENSTDkAm/**/*.wav" \
  --x-max 40
# Out:
# Found 1276 audio files under /media/mengh/SharedData/zhanh/Dataset/maestro-v3.0.0
# BSSL MAESTRO v3: 100%|██████████| 1276/1276 [30:58<00:00,  1.46s/file]
# Scanned MAESTRO v3: total frames = 35,862,275
# Zero-count hist bins: [(36.0, 36.5), (37.0, 37.5), (37.5, 38.0), (38.0, 38.5), (38.5, 39.0), (39.0, 39.5), (39.5, 40.0), (40.0, 40.5), (40.5, 41.0), (41.0, 41.5)]... total 87 bins
# Per-file loudness mean -> min 2.31, max 14.46, avg 7.26
# Saved: figures/bssl_dataset_stats/MAESTRO_v3_bssl.png
# Saved stats to: stats/bssl/MAESTRO_v3_bssl.json
# Found 50 audio files under /media/mengh/SharedData/zhanh/Dataset/SMD
# BSSL SMD: 100%|██████████| 50/50 [00:31<00:00,  1.61file/s]
# Scanned SMD: total frames = 849,873
# Zero-count hist bins: [(41.5, 42.0), (42.5, 43.0), (43.0, 43.5), (44.0, 44.5), (44.5, 45.0), (45.0, 45.5), (45.5, 46.0), (46.0, 46.5), (46.5, 47.0), (47.0, 47.5)]... total 75 bins
# Per-file loudness mean -> min 2.57, max 10.71, avg 5.80
# ...

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd() / "src"))

# %run -m data_analysis.analysis.dataset_bssl_stats \
  --dataset "FrancoisLeducGuitarDataset" \
  --root "/media/mengh/SharedData/zhanh/Dataset/FrancoisLeducGuitarDataset" \
  --x-max 40

# %run -m data_analysis.analysis.dataset_bssl_stats \
  --dataset "GOAT" \
  --root "/media/mengh/SharedData/zhanh/Dataset/GOAT" \
  --patterns "**/*.wav" "**/*.wav" \
  --x-max 40

# %run -m data_analysis.analysis.dataset_bssl_stats \
  --dataset "GAPS" \
  --root "/media/mengh/SharedData/zhanh/Dataset/GAPS" \
  --patterns "**/*.wav" "**/*.wav" \
  --x-max 40

# %run -m data_analysis.analysis.dataset_bssl_stats \
  --dataset "GuitarSet" \
  --root "/media/mengh/SharedData/zhanh/Dataset/guitarset" \
  --x-max 40
# Out:
# Found 88 audio files under /media/mengh/SharedData/zhanh/Dataset/FrancoisLeducGuitarDataset
# BSSL FrancoisLeducGuitarDataset: 100%|██████████| 88/88 [00:20<00:00,  4.22file/s]
# Scanned FrancoisLeducGuitarDataset: total frames = 827,217
# Zero-count hist bins: [(38.5, 39.0), (40.0, 40.5), (41.0, 41.5), (41.5, 42.0), (42.5, 43.0), (43.0, 43.5), (43.5, 44.0), (44.0, 44.5), (44.5, 45.0), (45.0, 45.5)]... total 78 bins
# Per-file loudness mean -> min 2.64, max 14.23, avg 7.43
# Saved: figures/bssl_dataset_stats/FrancoisLeducGuitarDataset_bssl.png
# Saved stats to: stats/bssl/FrancoisLeducGuitarDataset_bssl.json
# Found 1204 audio files under /media/mengh/SharedData/zhanh/Dataset/GOAT
# BSSL GOAT: 100%|██████████| 1204/1204 [04:17<00:00,  4.67file/s]
# Scanned GOAT: total frames = 7,517,889
# Zero-count hist bins: [(45.0, 45.5), (46.0, 46.5), (46.5, 47.0), (48.0, 48.5), (48.5, 49.0), (49.0, 49.5), (49.5, 50.0), (50.0, 50.5), (50.5, 51.0), (51.0, 51.5)]... total 67 bins
# ...

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd() / "src"))

# %run -m data_analysis.analysis.dataset_bssl_stats \
#   --dataset "MID-FiLD" \
#   --root "/media/mengh/SharedData/zhanh/Dataset/MID-FiLD_dataset"
#   --patterns "train/**/*.mid" "train/**/*.midi"

# %run -m data_analysis.analysis.dataset_bssl_stats \
  --dataset "MusicNet" \
  --root "/media/mengh/SharedData/zhanh/Dataset/MusicNet/musicnet" \
  --x-max 40
# Out:
# Found 330 audio files under /media/mengh/SharedData/zhanh/Dataset/MusicNet/musicnet
# BSSL MusicNet: 100%|██████████| 330/330 [09:13<00:00,  1.68s/file]
# Scanned MusicNet: total frames = 6,143,618
# Zero-count hist bins: [(50.5, 51.0), (52.0, 52.5), (53.0, 53.5), (53.5, 54.0), (54.0, 54.5), (54.5, 55.0), (55.0, 55.5), (55.5, 56.0), (56.0, 56.5), (56.5, 57.0)]... total 56 bins
# Per-file loudness mean -> min 2.60, max 17.84, avg 7.75
# Saved: figures/bssl_dataset_stats/MusicNet_bssl.png
# Saved stats to: stats/bssl/MusicNet_bssl.json

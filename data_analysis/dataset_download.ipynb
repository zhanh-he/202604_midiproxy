# %% [markdown]
# https://huggingface.co/datasets/xavriley/GAPS
#
# !pip install datasets huggingface_hub

# %%
# 1. 进入你的目标目录
cd /media/mengh/SharedData/zhanh/Dataset/GOAT-audio

# 2. 确保安装了 git-lfs (如果没有安装，sudo apt-get install git-lfs)
git lfs install

# 3. 直接克隆整个仓库
git clone https://huggingface.co/datasets/xavriley/GAPS

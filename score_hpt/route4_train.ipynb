# %%
# !python pytorch/train_proxy.py \
  exp.workspace="/media/datadisk/home/22828187/zhanh/202604_midiproxy/score_hpt/workspaces" \
  model.type="hpt" \
  score_informed.method="note_editor" \
  model.input2=onset model.input3=frame \
  loss.supervised_weight=0.0 loss.backend_weight=1.0 loss.velocity_prior_weight=0.0 \
  backend.enabled=true \
  backend.type=diffproxy \
  backend.project_root="/media/datadisk/home/22828187/zhanh/202604_midiproxy/synth-proxy" \
  backend.checkpoint="/path/to/your/sfproxy.ckpt" \
  backend.backend_segment_seconds=2.0 \
  backend.crop_mode=random \
  backend.supervision.hop_size=221 \
  backend.diffproxy.instrument_name=salamander_piano \
  backend.diffproxy.loss_type=smooth_l1 \
  backend.diffproxy.use_gt_aligned_note_events=true \
  backend.diffproxy.feature.hop=221 \
  wandb.comment="route4_diffproxy"

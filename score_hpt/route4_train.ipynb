# %%
# !python pytorch/train_proxy.py \
  exp.workspace="/media/datadisk/home/22828187/zhanh/202604_midiproxy/score_hpt/workspaces" \
  model.type="hpt" \
  score_informed.method="note_editor" \
  model.input2=onset model.input3=frame \
  loss.supervised_weight=0.0 loss.proxy_weight=1.0 loss.velocity_prior_weight=0.0 \
  proxy.enabled=true \
  proxy.type=diffproxy \
  proxy.project_root="/media/datadisk/home/22828187/zhanh/202604_midiproxy/synth-proxy" \
  proxy.checkpoint="/path/to/your/sfproxy.ckpt" \
  proxy.backend_segment_seconds=2.0 \
  proxy.crop_mode=random \
  proxy.supervision.hop_size=221 \
  proxy.sfproxy.instrument_name=salamander_piano \
  proxy.sfproxy.loss_type=smooth_l1 \
  proxy.sfproxy.use_gt_aligned_note_events=true \
  proxy.sfproxy.feature.hop=221 \
  wandb.comment="route4_diffproxy"
